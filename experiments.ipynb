# %%
import PyPDF2
from pathlib import Path

# %%
def extract_text_from_pdf(file_path):
    reader = PyPDF2.PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# %%
text = []

for pdf_file in Path("data").rglob("*.pdf"):
    text.append(extract_text_from_pdf(pdf_file))

# %%
text[2]
# Out:
# 'Diagnosis\nF43.24 Adjustment Disorder , With disturbance of conduct\nOliver ’s emotional and behavioral responses,including irritability , frustration, and outbursts, appear to be maladaptive reactions to  \nstressors, resulting in significant impairment in social and academic functioning. His conduct disturbances (e.g., emotional outbursts,  \ndifficulty following expectations, and oppositional behaviors) are not better explained by another mental disorder and have emerged in  \nthe context of adjustment to new environmental demands. Further assessment is needed to determine if the symptoms persist beyond  \nthe expected period of adjustment or if another primary diagnosis is more appropriate.\nCurrent Mental Status\nOrientation :X3: Oriented to Person, Place, and\nTime\nGeneral Appearance :Appropriate\nDress :Appropriate\nMotor Activity :Unremarkable\nInterview Behavior :Appropriate\nSpeech :Normal\nMood :Irritable\nAffect:AppropriateInsight :Good\nJudgment/Impulse Control :Good\nMemory :Intact\nAttention/Concentration :Good\nThought Process :Unremarkable\nThought Content :Appropriate\nPerception :Unremarkable\nFunctional Status :Mildly Impaired\nRisk Assessment\nPatient denies all areas of risk. No contrary clinical indications present.\nMedications\n"No he does n\'t take medication. "\nSubjective Report and Symptom Description\nOliver reported on his recent Thank sgiving, sharing that he had a large gathering with 14 kids and enjoyed a sleepover with neighborhood\nfriends . He discussed ongoi ng difficulties at school, including feeling isolated and bullied by peers, and expressed that he does not feel\ncomfortable sharing these experiences with his parents, fearing their reaction would be to tell him to "suck it up" rather than provide\nsuppor t. Oliver described his parents as generally unaware of the extent of his negative experiences at school. He also shared details\nabout  family dynamics, including discipline practices at home, such as consequences for breaking rules, and his strategies for avoiding\ndetection when breaking hous ehold rules. Oliver expressed a preference for staying with his mother, as she is less likely to discipline him.\nHe also discussed his academ ic experience, noting that he finds his current math class unchallenging and is interested in advancing to a\nhigher level. Oliver mentioned spendi ng summers in Hungary.\nObjective Content\nOliver was engaged and c ommunicative throughout the session, providing detailed responses to questions about his family, school, and\nsocial experiences. He demonstrated insight into his own coping strategies and family dynamics. Oliver appeared to have a good\n dummylink\nProgress Note\nMental W ealth Ambition - A  \nmarriage family and child  \ntherapy professional  \ncorporation\nClinician :Rebecca Gehlke Nolan, LMFT\nPatient :Oliver Zawicki, DOB 5/17/2014Date and T ime:11/29/2025 8:05 ᴀᴍ - 9:00 ᴀᴍ\nDuration : 55 minutes\nService Code :90837\nLocation : Telehealth - Pt Home\nParticipants : Client Only\nPage 1 of 3under standing of his academ ic strengths and areas of boredom. No behavioral outbursts or signs of acute distress were observed during\nthe session.\nTeleheal th:\nTherapist met with Oliver via teleheal th and complied with HIPAA requirements.\nTherapist was at the office during session.\nOliver was at home.\nInterventions Used\nThe following interventions were used: Exploration of Coping Patterns, Exploration of Emotions, Psycho-Education, and Supportive\nReflection.\nTreatment Plan Progress\nObjectives\n1. Oliver will identify and verbalize at least three emotions he experiences during times of distress and where he feels those emotions in\nhis body .\nProgress: Progressing\n2. Oliver will demonstrate a 50% decrease in distress during transitions at home or school, with a reduction in frequency or intensity of\nemotional outbursts\nProgress: Progressing\nAssessment / Additional Notes\nOliver continues  to experience social difficulties at school,  ...

# %%
import re


def extract_session_info(text):
    # Patterns
    clinician_pattern = r"Clinician\s*[:\-]\s*([A-Za-z\s]+(?:, [A-Za-z\s]+)*)"
    supervisor_pattern = r"Supervisor\s*[:\-]\s*([A-Za-z\s]+(?:, [A-Za-z\s]+)*)"
    patient_pattern = r"Patient\s*[:\-]\s*([A-Za-z\s]+)"
    dob_pattern = r"DOB\s*([0-9]{1,2}/[0-9]{1,2}/[0-9]{2,4})"
    date_pattern = r"Date and T(?:ime|ime)\s*[:\-]\s*([0-9/]+ [0-9:apm\s\-–]+)"
    duration_pattern = r"Duration\s*[:\-]\s*([0-9]+ ?minutes)"
    service_code_pattern = (
        r"Service Code\s*[:\-]\s*(\d{5})"  # CPT codes are 5-digit numeric
    )
    location_pattern = r"Location\s*[:\-]\s*([A-Za-z0-9\s\-]+)"
    participants_pattern = r"Participants\s*[:\-]\s*([A-Za-z\s;]+)"
    diagnosis_pattern = r"Diagnosis\s*[:\n]\s*([A-Z]\d{2}(?:\.\d+)?(?: [A-Za-z ,]+)?)"

    # Extract using regex
    clinician = re.search(clinician_pattern, text).split(',')[0]
    supervisor = re.search(supervisor_pattern, text).split(",")[0]
    patient = re.search(patient_pattern, text)
    dob = re.search(dob_pattern, text)
    date = re.search(date_pattern, text)
    duration = re.search(duration_pattern, text)
    service_code = re.search(service_code_pattern, text)
    location = re.search(location_pattern, text).split('/n')[0]
    participants = re.search(participants_pattern, text).split('/n')[0]
    diagnosis = re.search(diagnosis_pattern, text)

    result = {
        "Clinician": clinician.group(1).strip() if clinician else None,
        "Supervisor": supervisor.group(1).strip() if supervisor else None,
        "Patient": patient.group(1).strip() if patient else None,
        "DOB": dob.group(1).strip() if dob else None,
        "Date": date.group(1).strip() if date else None,
        "Duration": duration.group(1).strip() if duration else None,
        "Service Code": service_code.group(1).strip() if service_code else None,
        "Location": location.group(1).strip() if location else None,
        "Participants": participants.group(1).strip() if participants else None,
        "Diagnosis": diagnosis.group(1).strip() if diagnosis else None,
    }

    return result

# %%
import re


def extract_dos(text):
    phrase = "Date and"
    pattern = rf"{re.escape(phrase)}[^\d]*(\d{{1,2}}/\d{{1,2}}/\d{{4}})"
    matches = re.findall(pattern, text)
    return list(dict.fromkeys(matches))[0] if matches else None


def extract_session_info(text):
    # Patterns
    clinician_pattern = r"Clinician\s*[:\-]\s*([A-Za-z\s]+(?:, [A-Za-z\s]+)*)"
    supervisor_pattern = r"Supervisor\s*[:\-]\s*([A-Za-z\s]+(?:, [A-Za-z\s]+)*)"
    patient_pattern = r"Patient\s*[:\-]\s*([A-Za-z\s]+)"
    dob_pattern = r"DOB\s*[:\-]?\s*([0-9]{1,2}/[0-9]{1,2}/[0-9]{2,4})"
    duration_pattern = r"Duration\s*[:\-]\s*([0-9]+ ?minutes)"
    service_code_pattern = r"Service Code\s*[:\-]\s*(\d{5})"
    location_pattern = r"Location\s*[:\-]\s*([A-Za-z0-9\s\-]+)"
    participants_pattern = r"Participants\s*[:\-]\s*([A-Za-z\s;]+)"
    diagnosis_pattern = r"Diagnosis\s*[:\n]\s*([A-Z]\d{2}(?:\.\d+)?(?: [A-Za-z ,]+)?)"

    # Extract using regex
    clinician_match = re.search(clinician_pattern, text)
    supervisor_match = re.search(supervisor_pattern, text)
    patient_match = re.search(patient_pattern, text)
    dob_match = re.search(dob_pattern, text)
    date_match = extract_dos(text)
    duration_match = re.search(duration_pattern, text)
    service_code_match = re.search(service_code_pattern, text)
    location_match = re.search(location_pattern, text)
    participants_match = re.search(participants_pattern, text)
    diagnosis_match = re.search(diagnosis_pattern, text, re.MULTILINE)

    # Split and strip first item if multiple names
    clinician = (
        clinician_match.group(1).split(",")[0].strip() if clinician_match else None
    )
    supervisor = (
        supervisor_match.group(1).split(",")[0].strip() if supervisor_match else None
    )
    location = (
        location_match.group(1).split("\n")[0].strip() if location_match else None
    )
    participants = (
        participants_match.group(1).split("\n")[0].strip()
        if participants_match
        else None
    )

    result = {
        "Clinician": clinician,
        "Supervisor": supervisor,
        "Patient": patient_match.group(1).strip() if patient_match else None,
        "DOB": dob_match.group(1).strip() if dob_match else None,
        "Date": date_match if date_match else None,
        "Duration": duration_match.group(1).strip() if duration_match else None,
        "Service Code": service_code_match.group(1).strip()
        if service_code_match
        else None,
        "Location": location,
        "Participants": participants,
        "Diagnosis": diagnosis_match.group(1).strip() if diagnosis_match else None,
    }

    return result

# %%
info = []
for t in text:
    info.append(extract_session_info(t))

# %%
info[3]
# Out:
# {'Clinician': 'Noelle W ade',
#  'Supervisor': 'Rebecca Gehlke Nolan',
#  'Patient': 'Shelly Renee Marshall',
#  'DOB': '10/21/1990',
#  'Date': '12/1/2025',
#  'Duration': '80 minutes',
#  'Service Code': '90837',
#  'Location': 'In person',
#  'Participants': 'Client Only',
#  'Diagnosis': 'F32.0 Major Depressive Disorder , Recurrent episode, Mild'}

# %%
text[1]
# Out:
# "Diagnosis\nF43.23 Adjustment Disorder , With mixed anxiety and depressed mood\nThe client is experiencing significant emotional and behavioral distress related to the transition into marriage, which occurred about  \none year ago. He reports increased arguments, breakdowns in communication, and trust issues with his partner . These symptoms  \nhave intensified since the wedding and reflect dif ficulty adjusting to new relational dynamics, impacting his emotional well-being and  \nrelationship functioning\nMedications\nNone disclosed by partner.\nSubjective Report and Symptom Description\nThe client's partner attended the session alone to discuss her own experiences and concerns. She reported that the past week has been\nrough due to a back injury sustained while working out, resulting in ongoing pain and frustration about being unable to exercise. This has\nled to increased negat ive self-talk and stress about her weight and body image. She described a longstanding history of body image\nconcerns, rooted in childhood experiences of being compared to a thinner sibling and participating in weight loss clinics at a young age.\nShe shared ongoi ng struggles with body dysmorphia, fluctuating between feeling confident in her progress and being critical of herself,\nespecially when unabl e to work out or when facing upcoming weigh-ins. She also discussed anxiety related to shopping for clothes and\nattending social events where she might receive attention or compliments, linking these feelings to past trauma and a desire to avoid\nbeing noticed. She acknowledged progress in some areas, such as feeling more comfortable in gym clothes and participating in events\nlike Halloween in costume, but continues to experience distress around clothing choices and public perception. She also mentioned\nongoi ng respons ibilities related to her daughter's IEP and IHSS meetings, noting some positive experiences with advocacy and follow-up.\nObjective Content\nThe client's partner appear ed engage d and open during the session, participating in a candid discussion about her physical and emotional\nexperiences. She described her back pain in detail, noting limitations in mobility and the impact on her daily routine. She demonstrated\ninsight into the connec tion between her physical health, emotional well-being, and self-perception. She was able to articulate the origins of\nher body  image concerns and recognize patterns of negative self-talk. She also identified avoidance behaviors related to shopping and\nsocial events, as well as coping strategies she has used, such as seeking support from family and focusing on muscle gain rather than\nweight loss alone. She was receptive to therapeutic interventions and willing to consider new approaches to managing her anxiety and\nself-criticism.\n \nTeleheal th:\nTherapist met with the client via telehealth and complied with HIPAA requirements.\nTherapist was at their office during session.\nThe client's partner was at home during session.\nOutcome Measures\n dummylink\nProgress Note\nMental W ealth Ambition - A marriage  \nfamily and child therapy professional  \ncorporation\nClinician :Jeffrey Hagle, Associate Clinical Social W orker\nSupervisor :Rebecca Gehlke Nolan, LMFT\nPatient : Isaac Mejia, DOB 1 1/2/1999Date and T ime:11/26/2025 10:00 ᴀᴍ - 1 1:00 ᴀᴍ\nDuration : 60 minutes\nService Code :90846\nLocation : Telehealth - Pt Home\nParticipants : Partner; client not present\nPage 1 of 3Interventions Used\nThe following interventions were used: CBT , Cognitive Reframing, Exploration of Emotions, Mindfulness T raining, Psycho-Education,\nand Supportive Reflection.\nTreatment Plan Progress\nObjectives\n1. Over the course of six months, The client and his partner will identify and practice at least three new communication strategies to\nexpress needs , concerns, and emotions more effectively, with increased satisfaction reported by the couple in how they communicate.\nProgress: Progressing\n2. Over the cours ...
